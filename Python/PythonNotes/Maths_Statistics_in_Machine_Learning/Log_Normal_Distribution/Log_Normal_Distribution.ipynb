# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("Income.csv")
df.head()
# Out:
#    Income  Count
# 0    5000  15731
# 1   10000  11880
# 2   15000  21438
# 3   20000  22496
# 4   25000  22707

# %%
sns.set(rc={'figure.figsize':(20,10)}) # dictionary    'figure.figsize':(width,height)}
g = sns.barplot(x='Income',y='Count',data=df)
g.set_xticklabels(g.get_xticklabels(), 
                          rotation=45,
                        horizontalalignment='right');

# %% [markdown]
# ## Log Normal Distribution

# %%
sns.set(rc={'figure.figsize':(20,10)})
g = sns.barplot(x='Income',y='Count',data=df)
g.set_xticklabels(g.get_xticklabels(), 
                          rotation=45, 
                          horizontalalignment='right');
g.set(xscale="log");
